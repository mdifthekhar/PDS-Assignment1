# %%
pip install ISLP
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
raw_data=pd.read_csv('C:/Users/Moham/OneDrive/Documents/PDS_ASSIGNMENT1/2/raw_data/StudentsPerformance.csv')
raw_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
raw_data['test preparation course'].replace(['none', 'completed'],
                        [0, 1], inplace=True)

#Creating a new column total score
raw_data['result score'] = raw_data['math score'] + raw_data['writing score'] + raw_data['reading score']
raw_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
clean_data=raw_data.dropna()
clean_data
#Saving the clean data into the csv file
clean_data.to_csv('C:/Users/Moham/OneDrive/Documents/PDS_ASSIGNMENT1/2/clean_data/clean_data.csv')
